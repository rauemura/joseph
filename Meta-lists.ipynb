# %%
#coding UTF-8
import pandas as pd
import numpy as np
from pandas import Series,DataFrame

# %%
#data = {'a':[0, 1], 'b':[2, 3]}
#df = pd.DataFrame(data)
pokedict = {"bomanda":[7,"porigon2","yadoran","tekkaguya","parusyen","gaburiasu","kokeko"],
            "genga":[7,"porigon2","burakki","sazanndora","fero-tye","gaburiasu","girugarudo"],
            "gyaradosu":[6,"porigon2","ea-mudo","jibakoiru","kokeko","kuwaganon","asire-nu"],
            "tekkaguya":[10,"jibakoiru","kokeko","garagara","gaogaen","kuwagaron","ennyu-to"],
            "fero-tye":[7,"mimikkyu","girugarudo","gyaradosu","gaburiasu","gaogaen","garagara"],
            "kokeko":[20,"garagara","fero-tye","gibakoiru","kuwagaron","tetehu","gaburiasu"],
            "mimikkyu":[11,"jibakoiru","girugarudo","gyaradosu","parusyen","tekkaguya","metagurosu"],
            "meteno":[0,"tekkaguya","jibakoiru","kokeko","mimikkyu","rehire","tetehu"],
            "massibu-n":[7,"bo-mannda","tetehu","tekkaguya","mimikkyu","kokeko","gyaradosu"],
            "uturoid":[10,"girugarudo","tekkaguya","gaburiasu","jibakoiru","metagurosu","eamudo"],
            "garagara":[6,"rehire","genga","gaogaen","uturoid","gaburiasu","asire-nu"],
            "tetehu":[9,"girugarudo","rukario","jibakoiru","metagurosu","genga","bururu"],
            "gusokumusya":[6,"kokeko","jibakoiru","kuwagaron","uturoid","meteno","denjumoku"],
            "asire-nu":[6,"kokeko","jibakoiru","garu-ra","bo-manda","girugarudo","tekkaguya"],
            "gaburiasu":[7,"tekkaguya","porigon2","manmu","tetehu","gaburiasu","mimikkyu"],
            "girugarudo":[17,"migawari","gaogaen","garagara","gaburiasu",""],
            "sazandora":[5,"kokeko","mimikyu","gaburiasu","tetehu","bururu","rehire"],
            "denjumoku":[11,"","","","","","","",""],
            "rukario":[5,"","","","","","","",""],
            "porigonz":[2,"","","","","","","",""]}
            

pokemon = DataFrame(pokedict)
pokemon
# Out:
#     asire-nu bannbadoro    bomanda bururu denjumoku    fero-tye  gaburiasu  \
# 0          6          4          7      5        11           7          7
# 1     kokeko  tekkaguya   porigon2                     mimikkyu  tekkaguya
# 2  jibakoiru       mizu    yadoran                   girugarudo   porigon2
# 3    garu-ra       kusa  tekkaguya                       tasuki      koori
# 4   bo-manda               mannmu-                                   feary
# 5                         parusyen                               gaburiasu
# 6                        gaburiasu
# 7                           kokeko
# 8                        kuwaganon
#
#   garagara      garura       genga     ...         meteno    mimikkyu  \
# 0        6           2           7     ...              0          11
# 1     mizu   baruji-na    porigon2     ...      tekkaguya   jibakoiru
# 2  go-suto     burakki   baruji-na     ...      jibakoiru  girugarudo
# 3    jimen   tekkaguya     burakki     ...          kapus   gyaradosu
# 4      iwa    fero-tye  sazanndora     ...       mimikkyu
# 5      aku     rukario    fero-tye     ...           mizu
# 6           metagurosu   gaburiasu     ...
# 7           kiteruguma       manmu     ...
# 8                       girugarudo     ...
#
#      parusyen    perippa porigon2 rukario  sazandora  tekkaguya      tetehu  \
# 0           3          6        2       5          5         10           9
# 1  girugarudo     tasuki                       kapus  jibakoiru  girugarudo
# 2     rukario  jibakoiru                     mimikyu     kokeko     rukario
# 3                 kokeko                   gaburiasu   garagara   jibakoiru
# 4                                                                metagurosu
# 5
# 6
# 7
# 8
#
#       uturoid
# 0          10
# 1  girugarudo
# 2   tekkaguya
# 3   gaburiasu
# 4
# 5
# 6
# 7
# 8
#
# [9 rows x 31 columns]

# %%
""""
            """
